# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import urllib.parse

# %% [markdown]
# ### Multi pages - Las Vegas

# %%
# empty lists

address = []
bedrooms = []
bathrooms = []
area = []
year_build = []
parking = []
prices = []

# url_part_1 
url_part_1 = 'https://www.trulia.com'

for i in range(1,26):
    
    #website
    website: 'https://www.trulia.com/NV/Las_Vegas/'+ str(i) +'_p/'
    
    #request
    response = requests.get('https://www.trulia.com/NV/Las_Vegas/'+ str(i) +'_p/')

    #soup object
    soup= BeautifulSoup(response.content, 'html.parser')
    
    #result
    results = soup.find_all('li', {'class':'SearchResultsList__WideCell-b7y9ki-2'})
    results_update=[]
    for r in results:
        if r.has_attr('data-testid'):
            results_update.append(r)
    
    # relative url
    relative_url = []

    for item in results_update:
        for link in item.find_all('div',{'data-testid':'property-card-details'}):
            relative_url.append(link.find('a').get('href'))
    
    # create absolute url
    
    url_joined = []
    
    for link_2 in relative_url:
        url_joined.append(urllib.parse.urljoin(url_part_1, link_2))
    
    #loop through all joined links
    
    for link in url_joined:
        response = requests.get(link)

        soup = BeautifulSoup(response.content, 'html.parser')


        #address
        try:
            address.append(soup.find('span',{'data-testid':'home-details-summary-headline'}).get_text())
        except:
            address.append('')

        #bedrooms
        try:
            bedrooms.append(soup.find('li',{'data-testid':'bed'}).get_text())
        except:
            bedrooms.append('')

        #bathrooms
        try:
            bathrooms.append(soup.find('li',{'data-testid':'bath'}).get_text())
        except:
            bathrooms.append('')

        #area
        try:
            area.append(soup.find('li',{'data-testid':'floor'}).get_text())
        except:
            area.append('')

        #year build
        try:
            year_build.append(soup.find('div',string="Year Built").findNext('div').get_text())
        except:
            year_build.append('')

        #parking
        try:
            parking.append(soup.find('div',string="Parking").findNext('div').get_text())
        except:
            parking.append('')

        #prices
        try:
            prices.append(soup.find('h3',{'data-testid':'on-market-price-details'}).get_text())
        except:
            prices.append('')

# %%
real_estate_final = {'Address':address, 
               'Bedrooms':bedrooms, 
               'Bathrooms':bathrooms,
               'Area':area,
               'Year Build':year_build,
               'Parking':parking,
               'Price':prices,
                     
              }

# %%
real_estate_final = pd.DataFrame(real_estate_final)
real_estate_final['Location'] = 'Las Vegas'

# %%
real_estate_final.to_excel('real_estate_las_vegas.xlsx', index= False)

# %% [markdown]
# ### Multipages - Indianapolis

# %%
# empty lists

address = []
bedrooms = []
bathrooms = []
area = []
year_build = []
parking = []
prices = []

# url_part_1 
url_part_1 = 'https://www.trulia.com'

for i in range(1,26):
    
    #website
    website: 'https://www.trulia.com/IN/Indianapolis/'+ str(i) +'_p/'
    
    #request
    response = requests.get('https://www.trulia.com/IN/Indianapolis/'+ str(i) +'_p/')

    #soup object
    soup= BeautifulSoup(response.content, 'html.parser')
    
    #result
    results = soup.find_all('li', {'class':'SearchResultsList__WideCell-b7y9ki-2'})
    results_update=[]
    for r in results:
        if r.has_attr('data-testid'):
            results_update.append(r)
    
    # relative url
    relative_url = []

    for item in results_update:
        for link in item.find_all('div',{'data-testid':'property-card-details'}):
            relative_url.append(link.find('a').get('href'))
    
    # create absolute url
    
    url_joined = []
    
    for link_2 in relative_url:
        url_joined.append(urllib.parse.urljoin(url_part_1, link_2))
    
    #loop through all joined links
    
    for link in url_joined:
        response = requests.get(link)

        soup = BeautifulSoup(response.content, 'html.parser')


        #address
        try:
            address.append(soup.find('span',{'data-testid':'home-details-summary-headline'}).get_text())
        except:
            address.append('')

        #bedrooms
        try:
            bedrooms.append(soup.find('li',{'data-testid':'bed'}).get_text())
        except:
            bedrooms.append('')

        #bathrooms
        try:
            bathrooms.append(soup.find('li',{'data-testid':'bath'}).get_text())
        except:
            bathrooms.append('')

        #area
        try:
            area.append(soup.find('li',{'data-testid':'floor'}).get_text())
        except:
            area.append('')

        #year build
        try:
            year_build.append(soup.find('div',string="Year Built").findNext('div').get_text())
        except:
            year_build.append('')

        #parking
        try:
            parking.append(soup.find('div',string="Parking").findNext('div').get_text())
        except:
            parking.append('')

        #prices
        try:
            prices.append(soup.find('h3',{'data-testid':'on-market-price-details'}).get_text())
        except:
            prices.append('')

# %%
real_estate_final = {'Address':address, 
               'Bedrooms':bedrooms, 
               'Bathrooms':bathrooms,
               'Area':area,
               'Year Build':year_build,
               'Parking':parking,
               'Price':prices,
                     
              }

# %%
real_estate_final = pd.DataFrame(real_estate_final)
real_estate_final['Location'] = 'Indianapolis'

# %%
real_estate_final.to_excel('real_estate_indianapolis.xlsx', index= False)

# %% [markdown]
# ### Multiple Pages - Albuquerque

# %%
# empty lists

address = []
bedrooms = []
bathrooms = []
area = []
year_build = []
parking = []
prices = []

# url_part_1 
url_part_1 = 'https://www.trulia.com'

for i in range(1,26):
    
    #website
    website: 'https://www.trulia.com/NM/Albuquerque/'+ str(i) +'_p/'
    
    #request
    response = requests.get('https://www.trulia.com/NM/Albuquerque/'+ str(i) +'_p/')

    #soup object
    soup= BeautifulSoup(response.content, 'html.parser')
    
    #result
    results = soup.find_all('li', {'class':'SearchResultsList__WideCell-b7y9ki-2'})
    results_update=[]
    for r in results:
        if r.has_attr('data-testid'):
            results_update.append(r)
    
    # relative url
    relative_url = []

    for item in results_update:
        for link in item.find_all('div',{'data-testid':'property-card-details'}):
            relative_url.append(link.find('a').get('href'))
    
    # create absolute url
    
    url_joined = []
    
    for link_2 in relative_url:
        url_joined.append(urllib.parse.urljoin(url_part_1, link_2))
    
    #loop through all joined links
    
    for link in url_joined:
        response = requests.get(link)

        soup = BeautifulSoup(response.content, 'html.parser')


        #address
        try:
            address.append(soup.find('span',{'data-testid':'home-details-summary-headline'}).get_text())
        except:
            address.append('')

        #bedrooms
        try:
            bedrooms.append(soup.find('li',{'data-testid':'bed'}).get_text())
        except:
            bedrooms.append('')

        #bathrooms
        try:
            bathrooms.append(soup.find('li',{'data-testid':'bath'}).get_text())
        except:
            bathrooms.append('')

        #area
        try:
            area.append(soup.find('li',{'data-testid':'floor'}).get_text())
        except:
            area.append('')

        #year build
        try:
            year_build.append(soup.find('div',string="Year Built").findNext('div').get_text())
        except:
            year_build.append('')

        #parking
        try:
            parking.append(soup.find('div',string="Parking").findNext('div').get_text())
        except:
            parking.append('')

        #prices
        try:
            prices.append(soup.find('h3',{'data-testid':'on-market-price-details'}).get_text())
        except:
            prices.append('')

# %%
real_estate_final = {'Address':address, 
               'Bedrooms':bedrooms, 
               'Bathrooms':bathrooms,
               'Area':area,
               'Year Build':year_build,
               'Parking':parking,
               'Price':prices,
                     
              }

# %%
real_estate_final = pd.DataFrame(real_estate_final)
real_estate_final['Location'] = 'Albuquerque'

# %%
real_estate_final.to_excel('real_estate_albuquerque.xlsx', index= False)

# %% [markdown]
# ### Multipage - Colorado

# %%
# empty lists

address = []
bedrooms = []
bathrooms = []
area = []
year_build = []
parking = []
prices = []

# url_part_1 
url_part_1 = 'https://www.trulia.com'

for i in range(1,26):
    
    #website
    website: 'https://www.trulia.com/NM/Albuquerque/'+ str(i) +'_p/'
    
    #request
    response = requests.get('https://www.trulia.com/CO/Colorado_Springs/'+ str(i) +'_p/')

    #soup object
    soup= BeautifulSoup(response.content, 'html.parser')
    
    #result
    results = soup.find_all('li', {'class':'SearchResultsList__WideCell-b7y9ki-2'})
    results_update=[]
    for r in results:
        if r.has_attr('data-testid'):
            results_update.append(r)
    
    # relative url
    relative_url = []

    for item in results_update:
        for link in item.find_all('div',{'data-testid':'property-card-details'}):
            relative_url.append(link.find('a').get('href'))
    
    # create absolute url
    
    url_joined = []
    
    for link_2 in relative_url:
        url_joined.append(urllib.parse.urljoin(url_part_1, link_2))
    
    #loop through all joined links
    
    for link in url_joined:
        response = requests.get(link)

        soup = BeautifulSoup(response.content, 'html.parser')


        #address
        try:
            address.append(soup.find('span',{'data-testid':'home-details-summary-headline'}).get_text())
        except:
            address.append('')

        #bedrooms
        try:
            bedrooms.append(soup.find('li',{'data-testid':'bed'}).get_text())
        except:
            bedrooms.append('')

        #bathrooms
        try:
            bathrooms.append(soup.find('li',{'data-testid':'bath'}).get_text())
        except:
            bathrooms.append('')

        #area
        try:
            area.append(soup.find('li',{'data-testid':'floor'}).get_text())
        except:
            area.append('')

        #year build
        try:
            year_build.append(soup.find('div',string="Year Built").findNext('div').get_text())
        except:
            year_build.append('')

        #parking
        try:
            parking.append(soup.find('div',string="Parking").findNext('div').get_text())
        except:
            parking.append('')

        #prices
        try:
            prices.append(soup.find('h3',{'data-testid':'on-market-price-details'}).get_text())
        except:
            prices.append('')

# %%
real_estate_final = {'Address':address, 
               'Bedrooms':bedrooms, 
               'Bathrooms':bathrooms,
               'Area':area,
               'Year Build':year_build,
               'Parking':parking,
               'Price':prices,
                     
              }

# %%
real_estate_final = pd.DataFrame(real_estate_final)
real_estate_final['Location'] = 'Colorado'
real_estate_final.to_excel('real_estate_colorado.xlsx', index= False)

# %% [markdown]
# ### Multipage - Philadelphia

# %%
# empty lists

address = []
bedrooms = []
bathrooms = []
area = []
year_build = []
parking = []
prices = []

# url_part_1 
url_part_1 = 'https://www.trulia.com'

for i in range(1,26):
    
    #website
    website: 'https://www.trulia.com/NM/Albuquerque/'+ str(i) +'_p/'
    
    #request
    response = requests.get('https://www.trulia.com/PA/Philadelphia/'+ str(i) +'_p/')

    #soup object
    soup= BeautifulSoup(response.content, 'html.parser')
    
    #result
    results = soup.find_all('li', {'class':'SearchResultsList__WideCell-b7y9ki-2'})
    results_update=[]
    for r in results:
        if r.has_attr('data-testid'):
            results_update.append(r)
    
    # relative url
    relative_url = []

    for item in results_update:
        for link in item.find_all('div',{'data-testid':'property-card-details'}):
            relative_url.append(link.find('a').get('href'))
    
    # create absolute url
    
    url_joined = []
    
    for link_2 in relative_url:
        url_joined.append(urllib.parse.urljoin(url_part_1, link_2))
    
    #loop through all joined links
    
    for link in url_joined:
        response = requests.get(link)

        soup = BeautifulSoup(response.content, 'html.parser')


        #address
        try:
            address.append(soup.find('span',{'data-testid':'home-details-summary-headline'}).get_text())
        except:
            address.append('')

        #bedrooms
        try:
            bedrooms.append(soup.find('li',{'data-testid':'bed'}).get_text())
        except:
            bedrooms.append('')

        #bathrooms
        try:
            bathrooms.append(soup.find('li',{'data-testid':'bath'}).get_text())
        except:
            bathrooms.append('')

        #area
        try:
            area.append(soup.find('li',{'data-testid':'floor'}).get_text())
        except:
            area.append('')

        #year build
        try:
            year_build.append(soup.find('div',string="Year Built").findNext('div').get_text())
        except:
            year_build.append('')

        #parking
        try:
            parking.append(soup.find('div',string="Parking").findNext('div').get_text())
        except:
            parking.append('')

        #prices
        try:
            prices.append(soup.find('h3',{'data-testid':'on-market-price-details'}).get_text())
        except:
            prices.append('')

# %%
real_estate_final = {'Address':address, 
               'Bedrooms':bedrooms, 
               'Bathrooms':bathrooms,
               'Area':area,
               'Year Build':year_build,
               'Parking':parking,
               'Price':prices,
                     
              }

# %%
real_estate_final = pd.DataFrame(real_estate_final)
real_estate_final['Location'] = 'Philadelphia'
real_estate_final.to_excel('real_estate_philadelphia.xlsx', index= False)
